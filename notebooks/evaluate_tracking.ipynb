# %%
# %reload_ext autoreload
# %autoreload 2

import joblib
from tqdm import tqdm
import numpy as np
from matplotlib import pyplot as plt

from vrAnalysis2.database import get_database
from vrAnalysis2.helpers import Timer, print_all_keys
from vrAnalysis2.sessions import create_b2session
from vrAnalysis2.processors.spkmaps import SpkmapProcessor
from vrAnalysis2.tracking import Tracker
from vrAnalysis2 import files
from vrAnalysis2 import helpers
from syd import Viewer

sessiondb = get_database("vrSessions")
mousedb = get_database("vrMice")
tracked_mice = mousedb.get_table(tracked=True)["mouseName"].unique()

# %%
class TrackerViewer(Viewer):
    def __init__(self, tracked_mice: list[str]):
        self.tracked_mice = list(tracked_mice)
        self.add_selection("mouse", value=self.tracked_mice[0], options=self.tracked_mice)
        self.add_boolean("distribution", value=True)
        self._trackers = {mouse: None for mouse in self.tracked_mice}
        self._mouse_data = {mouse: None for mouse in self.tracked_mice}

    def get_tracker(self, mouse: str) -> Tracker:
        if self._trackers[mouse] is None:
            self._trackers[mouse] = Tracker(mouse)
        return self._trackers[mouse]
    
    def get_mouse_data(self, mouse: str):
        if self._mouse_data[mouse] is not None:
            return self._mouse_data[mouse]
        
        tracker = self.get_tracker(mouse)
        num_clusters = tracker.cluster_silhouettes.shape[0]
        num_sessions = len(tracker.sessions)
        cluster_in_session = np.zeros((num_clusters, num_sessions), dtype=bool)
        red_assignment = np.full((num_clusters, num_sessions), np.nan)
        cluster_silhouettes = tracker.cluster_silhouettes

        for isession, session in enumerate(tracker.sessions):
            idx_valid_labels = tracker.labels[isession] != -1
            valid_labels = tracker.labels[isession][idx_valid_labels]
            cluster_in_session[valid_labels, isession] = True
            red_values = session.get_red_idx()
            red_assignment[valid_labels, isession] = red_values[idx_valid_labels]

        self._mouse_data[mouse] = (cluster_in_session, red_assignment, cluster_silhouettes)
        return self._mouse_data[mouse]

    def plot(self, state):
        cluster_in_session, red_assignment, cluster_silhouettes = self.get_mouse_data(state["mouse"])

        num_sessions = np.sum(cluster_in_session, axis=1)

        any_red = np.any(red_assignment == 1, axis=1)
        red_assignment = red_assignment[any_red]
        num_sessions_red = num_sessions[any_red]
        cluster_silhouettes = cluster_silhouettes[any_red]
        fraction_assignment = []
        for inumses in range(2, num_sessions_red.max() + 1):
            itracked = num_sessions_red == inumses
            fraction = np.sum(red_assignment[itracked] == 1, axis=1) / inumses
            fraction_assignment.append(fraction)

        fraction_sessions_red = np.sum(red_assignment == 1, axis=1) / num_sessions_red

        fig, ax = plt.subplots(1, 3, figsize=(8, 3), layout="constrained")
        ax[0].hist(num_sessions, bins=np.arange(0, num_sessions.max() + 1) + 0.5, rwidth=0.9)
        ax[0].set_xlabel("Number of sessions per cluster")
        ax[0].set_ylabel("Number of clusters")

        if state["distribution"]:
            ax[1].violinplot(fraction_assignment, range(2, num_sessions_red.max() + 1), showmeans=False, showextrema=False)
        else:
            ax[1].plot(range(2, num_sessions_red.max() + 1), [np.mean(frac) for frac in fraction_assignment])
        ax[1].set_xlabel("Number of sessions per cluster")
        ax[1].set_ylabel("Fraction of sessions per cluster")


        fraction_bins = np.linspace(0, 1, 10)
        idx_fraction = np.digitize(fraction_sessions_red, fraction_bins, right=True)
        bins = np.linspace(-1, 1, 9)
        counts = []
        for ifraction in range(1, len(fraction_bins)):
            idx = np.where(idx_fraction == ifraction)[0]
            ccounts = np.histogram(cluster_silhouettes[idx], bins=bins)[0]
            counts.append(ccounts / np.sum(ccounts))
        ax[2].imshow(np.stack(counts, axis=0), cmap="plasma", aspect="auto", interpolation="none", origin="lower", extent=[bins[0], bins[-1], 0, 1])
        ax[2].set_xlabel("Cluster silhouette")
        ax[2].set_ylabel("Fraction of sessions per cluster")

        return fig
    
viewer = TrackerViewer(tracked_mice).deploy(env="notebook")
# Out:
# HBox(children=(VBox(children=(VBox(children=(HTML(value='<b>Parameters</b>'), Dropdown(description='mouse', la…
# C:\Users\Andrew\AppData\Local\Temp\ipykernel_12580\1523807161.py:72: RuntimeWarning: invalid value encountered in divide
#   counts.append(ccounts / np.sum(ccounts))

# %%
# NOTES FOR TOMORROW
# Gotta include the red cell in the tracking (and look at cluster quality stuffs etc)
# Maybe consider only some clusters and also ignore the red cell inclusion based on sample silhouette?

# %%
from vrAnalysis2.tracking import Tracker
tracker = Tracker("ATL022")

# %%
print(print_all_keys(tracker.rundata[0], ignore_keys=["_system_info"]))
# Out:
# data : dict
#     _verbose : bool
#     type : dict
#         __module__ : str
#         __doc__ : str
#         __init__ : dict
#         import_FOV_images : dict
#         import_spatialFootprints : dict
#         import_neuropil_masks : dict
#         _make_shifts : dict
#         _transform_statFile_to_spatialFootprints : dict
#             __module__ : str
#             __name__ : str
#             __qualname__ : str
#             __doc__ : str
#             __annotations__ : dict
#                 frame_height_width : dict
#                     __repr__ : str
#                 stat : dict
#                     __new__ : builtin_function_or_method
#                     __repr__ : wrapper_descriptor
#                     __str__ : wrapper_descriptor
#                     __lt__ : wrapper_descriptor
#                     __le__ : wrapper_descriptor
#                     __eq__ : wrapper_descriptor
#                     __ne__ : wrapper_descriptor
#                     __gt__ : wrapper_descriptor
#                     __ge__ : wrapper_descriptor
#                     __iter__ : wrapper_descriptor
#                     __add__ : wrapper_descriptor
#                     __radd__ : wrapper_descriptor
#                     __sub__ : wrapper_descriptor
#                     __rsub__ : wrapper_descriptor
#                     __mul__ : wrapper_descriptor
#                     __rmul__ : wrapper_descriptor
#                     __mod__ : wrapper_descriptor
#                     __rmod__ : wrapper_descriptor
#                     __divmod__ : wrapper_descriptor
#                     __rdivmod__ : wrapper_descriptor
#                     __pow__ : wrapper_descriptor
#                     __rpow__ : wrapper_descriptor
#                     __neg__ : wrapper_descriptor
#                     __pos__ : wrapper_descriptor
#                     __abs__ : wrapper_descriptor
#                     __bool__ : wrapper_descriptor
#                     __invert__ : wrapper_descriptor
#                     __lshift__ : wrapper_descriptor
#                     __rlshift__ : wrapper_descriptor
#                     __rshift__ : wrapper_descriptor
#                     __rrshift__ : wrapper_descriptor
#                     __and__ : wrapper_descriptor
#                     __rand__ : wrapper_descriptor
#                     __xor__ : wrapper_descriptor
#                     __rxor__ : wrapper_descriptor
#                     __or__ : wrapper_descriptor
#                     __ror__ : wrapper_descriptor
#                     __int__ : wrapper_descriptor
#                     __float__ : wrapper_descriptor
#                     __iadd__ : wrapper_descriptor
#                     __isub__ : wrapper_descriptor
#                     __imul__ : wrapper_descriptor
#                     __imod__ : wrapper_descriptor
#                     __ipow__ : wrapper_descriptor
#                     __ilshift__ : wrapper_descriptor
#                     __irshift__ : wrapper_descriptor
#                     __iand__ : wrapper_descriptor
#                     __ixor__ : wrapper_descriptor
#                     __ior__ : wrapper_descriptor
#                     __floordiv__ : wrapper_descriptor
#                     __rfloordiv__ : wrapper_descriptor
#                     __truediv__ : wrapper_descriptor
#                     __rtruediv__ : wrapper_descriptor
#                     __ifloordiv__ : wrapper_descriptor
#                     __itruediv__ : wrapper_descriptor
#                     __index__ : wrapper_descriptor
#                     __matmul__ : wrapper_descriptor
#                     __rmatmul__ : wrapper_descriptor
#                     __imatmul__ : wrapper_descriptor
#                     __len__ : wrapper_descriptor
#                     __getitem__ : wrapper_descriptor
#                     __setitem__ : wrapper_descriptor
#                     __delitem__ : wrapper_descriptor
#                     __contains__ : wrapper_descriptor
#                     __array__ : method_descriptor
#                     __array_prepare__ : method_descriptor
#                     __array_finalize__ : method_descriptor
#                     __array_wrap__ : method_descriptor
#                     __array_ufunc__ : method_descriptor
#                     __array_function__ : method_descriptor
#                     __sizeof__ : method_descriptor
#                     __copy__ : method_descriptor
#                     __deepcopy__ : method_descriptor
#                     __reduce__ : method_descriptor
#                     __reduce_ex__ : method_descriptor
#                     __setstate__ : method_descriptor
#                     dumps : method_descriptor
#                     dump : method_descriptor
#                     __complex__ : method_descriptor
#                     __format__ : method_descriptor
#                     __class_getitem__ : dict
#                         __repr__ : str
#                     all : method_descriptor
#                     any : method_descriptor
#                     argmax : method_descriptor
#                     argmin : method_descriptor
#                     argpartition : method_descriptor
#                     argsort : method_descriptor
#                     astype : method_descriptor
#                     byteswap : method_descriptor
#                     choose : method_descriptor
#                     clip : method_descriptor
#                     compress : method_descriptor
#                     conj : method_descriptor
#                     conjugate : method_descriptor
#                     copy : method_descriptor
#                     cumprod : method_descriptor
#                     cumsum : method_descriptor
#                     diagonal : method_descriptor
#                     dot : method_descriptor
#                     fill : method_descriptor
#                     flatten : method_descriptor
#                     getfield : method_descriptor
#                     item : method_descriptor
#                     itemset : method_descriptor
#                     max : method_descriptor
#                     mean : method_descriptor
#                     min : method_descriptor
#                     newbyteorder : method_descriptor
#                     nonzero : method_descriptor
#                     partition : method_descriptor
#                     prod : method_descriptor
#                     ptp : method_descriptor
#                     put : method_descriptor
#                     ravel : method_descriptor
#                     repeat : method_descriptor
#                     reshape : method_descriptor
#                     resize : method_descriptor
#                     round : method_descriptor
#                     searchsorted : method_descriptor
#                     setfield : method_descriptor
#                     setflags : method_descriptor
#                     sort : method_descriptor
#                     squeeze : method_descriptor
#                     std : method_descriptor
#                     sum : method_descriptor
#                     swapaxes : method_descriptor
#                     take : method_descriptor
#                     tobytes : method_descriptor
#                     tofile : method_descriptor
#                     tolist : method_descriptor
#                     tostring : method_descriptor
#                     trace : method_descriptor
#                     transpose : method_descriptor
#                     var : method_descriptor
#                     view : method_descriptor
#                     __dlpack__ : method_descriptor
#                     __dlpack_device__ : method_descriptor
#                     ndim : dict
#                         __repr__ : str
#                     flags : dict
#                         __repr__ : str
#                     shape : dict
#                         __repr__ : str
#                     strides : dict
#                         __repr__ : str
#                     data : dict
#                         __repr__ : str
#                     itemsize : dict
#                         __repr__ : str
#                     size : dict
#                         __repr__ : str
#                     nbytes : dict
#                         __repr__ : str
#                     base : dict
#                         __repr__ : str
#                     dtype : dict
#                         __repr__ : str
#                     real : dict
#                         __repr__ : str
#                     imag : dict
#                         __repr__ : str
#                     flat : dict
#                         __repr__ : str
#                     ctypes : dict
#                         __repr__ : str
#                     T : dict
#                         __repr__ : str
#                     __array_interface__ : dict
#                         __repr__ : str
#                     __array_struct__ : dict
#                         __repr__ : str
#                     __array_priority__ : dict
#                         __repr__ : str
#                     __doc__ : str
#                     __hash__ : NoneType
#                 shifts : dict
#                     __repr__ : str
#                 dtype : dict
#                     __repr__ : str
#                 normalize_mask : dict
#                     __new__ : builtin_function_or_method
#                     __repr__ : wrapper_descriptor
#                     __and__ : wrapper_descriptor
#                     __rand__ : wrapper_descriptor
#                     __xor__ : wrapper_descriptor
#                     __rxor__ : wrapper_descriptor
#                     __or__ : wrapper_descriptor
#                     __ror__ : wrapper_descriptor
#                     __doc__ : str
#                 return : dict
#                     __module__ : str
#                     __doc__ : str
#                     __div__ : dict
#                     __mul__ : dict
#                     __add__ : dict
#                     __sub__ : dict
#                     __le__ : dict
#                     __eq__ : dict
#                     __lt__ : dict
#                     __gt__ : dict
#                     __slotnames__ : list
#         _transform_statFile_to_neuropilMasks : dict
#             __module__ : str
#             __name__ : str
#             __qualname__ : str
#             __doc__ : str
#             __annotations__ : dict
#                 frame_height_width : dict
#                     __repr__ : str
#                 stat : dict
#                     __new__ : builtin_function_or_method
#                     __repr__ : wrapper_descriptor
#                     __str__ : wrapper_descriptor
#                     __lt__ : wrapper_descriptor
#                     __le__ : wrapper_descriptor
#                     __eq__ : wrapper_descriptor
#                     __ne__ : wrapper_descriptor
#                     __gt__ : wrapper_descriptor
#                     __ge__ : wrapper_descriptor
#                     __iter__ : wrapper_descriptor
#                     __add__ : wrapper_descriptor
#                     __radd__ : wrapper_descriptor
#                     __sub__ : wrapper_descriptor
#                     __rsub__ : wrapper_descriptor
#                     __mul__ : wrapper_descriptor
#                     __rmul__ : wrapper_descriptor
#                     __mod__ : wrapper_descriptor
#                     __rmod__ : wrapper_descriptor
#                     __divmod__ : wrapper_descriptor
#                     __rdivmod__ : wrapper_descriptor
#                     __pow__ : wrapper_descriptor
#                     __rpow__ : wrapper_descriptor
#                     __neg__ : wrapper_descriptor
#                     __pos__ : wrapper_descriptor
#                     __abs__ : wrapper_descriptor
#                     __bool__ : wrapper_descriptor
#                     __invert__ : wrapper_descriptor
#                     __lshift__ : wrapper_descriptor
#                     __rlshift__ : wrapper_descriptor
#                     __rshift__ : wrapper_descriptor
#                     __rrshift__ : wrapper_descriptor
#                     __and__ : wrapper_descriptor
#                     __rand__ : wrapper_descriptor
#                     __xor__ : wrapper_descriptor
#                     __rxor__ : wrapper_descriptor
#                     __or__ : wrapper_descriptor
#                     __ror__ : wrapper_descriptor
#                     __int__ : wrapper_descriptor
#                     __float__ : wrapper_descriptor
#                     __iadd__ : wrapper_descriptor
#                     __isub__ : wrapper_descriptor
#                     __imul__ : wrapper_descriptor
#                     __imod__ : wrapper_descriptor
#                     __ipow__ : wrapper_descriptor
#                     __ilshift__ : wrapper_descriptor
#                     __irshift__ : wrapper_descriptor
#                     __iand__ : wrapper_descriptor
#                     __ixor__ : wrapper_descriptor
#                     __ior__ : wrapper_descriptor
#                     __floordiv__ : wrapper_descriptor
#                     __rfloordiv__ : wrapper_descriptor
#                     __truediv__ : wrapper_descriptor
#                     __rtruediv__ : wrapper_descriptor
#                     __ifloordiv__ : wrapper_descriptor
#                     __itruediv__ : wrapper_descriptor
#                     __index__ : wrapper_descriptor
#                     __matmul__ : wrapper_descriptor
#                     __rmatmul__ : wrapper_descriptor
#                     __imatmul__ : wrapper_descriptor
#                     __len__ : wrapper_descriptor
#                     __getitem__ : wrapper_descriptor
#                     __setitem__ : wrapper_descriptor
#                     __delitem__ : wrapper_descriptor
#                     __contains__ : wrapper_descriptor
#                     __array__ : method_descriptor
#                     __array_prepare__ : method_descriptor
#                     __array_finalize__ : method_descriptor
#                     __array_wrap__ : method_descriptor
#                     __array_ufunc__ : method_descriptor
#                     __array_function__ : method_descriptor
#                     __sizeof__ : method_descriptor
#                     __copy__ : method_descriptor
#                     __deepcopy__ : method_descriptor
#                     __reduce__ : method_descriptor
#                     __reduce_ex__ : method_descriptor
#                     __setstate__ : method_descriptor
#                     dumps : method_descriptor
#                     dump : method_descriptor
#                     __complex__ : method_descriptor
#                     __format__ : method_descriptor
#                     __class_getitem__ : dict
#                         __repr__ : str
#                     all : method_descriptor
#                     any : method_descriptor
#                     argmax : method_descriptor
#                     argmin : method_descriptor
#                     argpartition : method_descriptor
#                     argsort : method_descriptor
#                     astype : method_descriptor
#                     byteswap : method_descriptor
#                     choose : method_descriptor
#                     clip : method_descriptor
#                     compress : method_descriptor
#                     conj : method_descriptor
#                     conjugate : method_descriptor
#                     copy : method_descriptor
#                     cumprod : method_descriptor
#                     cumsum : method_descriptor
#                     diagonal : method_descriptor
#                     dot : method_descriptor
#                     fill : method_descriptor
#                     flatten : method_descriptor
#                     getfield : method_descriptor
#                     item : method_descriptor
#                     itemset : method_descriptor
#                     max : method_descriptor
#                     mean : method_descriptor
#                     min : method_descriptor
#                     newbyteorder : method_descriptor
#                     nonzero : method_descriptor
#                     partition : method_descriptor
#                     prod : method_descriptor
#                     ptp : method_descriptor
#                     put : method_descriptor
#                     ravel : method_descriptor
#                     repeat : method_descriptor
#                     reshape : method_descriptor
#                     resize : method_descriptor
#                     round : method_descriptor
#                     searchsorted : method_descriptor
#                     setfield : method_descriptor
#                     setflags : method_descriptor
#                     sort : method_descriptor
#                     squeeze : method_descriptor
#                     std : method_descriptor
#                     sum : method_descriptor
#                     swapaxes : method_descriptor
#                     take : method_descriptor
#                     tobytes : method_descriptor
#                     tofile : method_descriptor
#                     tolist : method_descriptor
#                     tostring : method_descriptor
#                     trace : method_descriptor
#                     transpose : method_descriptor
#                     var : method_descriptor
#                     view : method_descriptor
#                     __dlpack__ : method_descriptor
#                     __dlpack_device__ : method_descriptor
#                     ndim : dict
#                         __repr__ : str
#                     flags : dict
#                         __repr__ : str
#                     shape : dict
#                         __repr__ : str
#                     strides : dict
#                         __repr__ : str
#                     data : dict
#                         __repr__ : str
#                     itemsize : dict
#                         __repr__ : str
#                     size : dict
#                         __repr__ : str
#                     nbytes : dict
#                         __repr__ : str
#                     base : dict
#                         __repr__ : str
#                     dtype : dict
#                         __repr__ : str
#                     real : dict
#                         __repr__ : str
#                     imag : dict
#                         __repr__ : str
#                     flat : dict
#                         __repr__ : str
#                     ctypes : dict
#                         __repr__ : str
#                     T : dict
#                         __repr__ : str
#                     __array_interface__ : dict
#                         __repr__ : str
#                     __array_struct__ : dict
#                         __repr__ : str
#                     __array_priority__ : dict
#                         __repr__ : str
#                     __doc__ : str
#                     __hash__ : NoneType
#                 shifts : dict
#                     __repr__ : str
#                 return : dict
#                     __module__ : str
#                     __doc__ : str
#                     __div__ : dict
#                     __mul__ : dict
#                     __add__ : dict
#                     __sub__ : dict
#                     __le__ : dict
#                     __eq__ : dict
#                     __lt__ : dict
#                     __gt__ : dict
#                     __slotnames__ : list
#     paths_stat : list
#     paths_ops : list
#     n_sessions : int
#     shifts : list
#     FOV_height : int
#     FOV_width : int
#     FOV_images : list
#     spatialFootprints : list
#     um_per_pixel : float
#     n_roi : list
#     n_roi_total : int
#     session_bool : ndarray
#     centroids : list
#     ROI_images : list
# aligner : dict
#     _verbose : bool
#     remappingIdx_geo : ndarray
#     warp_matrices : ndarray
#     remappingIdx_nonrigid : ndarray
#     _HW : list
#     mask_geo : ndarray
#     ims_registered_geo : list
#     ims_registered_nonrigid : list
#     ROIs_aligned : list
# blurrer : dict
#     _frame_shape : list
#     _verbose : bool
#     _width : int
#     _kernel_size : int
#     kernel : ndarray
#     _conv : dict
#         k : ndarray
#         mode : str
#         x_shape : list
#         dtype : dict
#             __new__ : builtin_function_or_method
#             __repr__ : wrapper_descriptor
#             __hash__ : wrapper_descriptor
#             __str__ : wrapper_descriptor
#             __lt__ : wrapper_descriptor
#             __le__ : wrapper_descriptor
#             __eq__ : wrapper_descriptor
#             __ne__ : wrapper_descriptor
#             __gt__ : wrapper_descriptor
#             __ge__ : wrapper_descriptor
#             __add__ : wrapper_descriptor
#             __radd__ : wrapper_descriptor
#             __sub__ : wrapper_descriptor
#             __rsub__ : wrapper_descriptor
#             __mul__ : wrapper_descriptor
#             __rmul__ : wrapper_descriptor
#             __mod__ : wrapper_descriptor
#             __rmod__ : wrapper_descriptor
#             __divmod__ : wrapper_descriptor
#             __rdivmod__ : wrapper_descriptor
#             __pow__ : wrapper_descriptor
#             __rpow__ : wrapper_descriptor
#             __neg__ : wrapper_descriptor
#             __pos__ : wrapper_descriptor
#             __abs__ : wrapper_descriptor
#             __bool__ : wrapper_descriptor
#             __int__ : wrapper_descriptor
#             __float__ : wrapper_descriptor
#             __floordiv__ : wrapper_descriptor
#             __rfloordiv__ : wrapper_descriptor
#             __truediv__ : wrapper_descriptor
#             __rtruediv__ : wrapper_descriptor
#             as_integer_ratio : method_descriptor
#             is_integer : method_descriptor
#             __class_getitem__ : dict
#                 __repr__ : str
#             __doc__ : str
#         so : list
#         dt : dict
#             _shape : list
#             maxprint : int
#             indices : ndarray
#             indptr : ndarray
#             data : ndarray
#             _has_canonical_format : bool
#             _has_sorted_indices : bool
#     ROIs_blurred : list
# roinet : dict
#     _device : str
#     _verbose : bool
#     _dir_networkFiles : str
#     _download_url : str
#     _download_path_save : str
#     params_model : dict
#         paths : dict
#             dir_github : str
#             fileName_save_model : str
#             path_data_training : str
#         prefs : dict
#             saveModelIteratively : bool
#             saveLogs : bool
#             log_print : bool
#             log_save : bool
#         useGPU_training : bool
#         useGPU_dataloader : bool
#         dataloader_kwargs : dict
#             batch_size : int
#             shuffle : bool
#             drop_last : bool
#             pin_memory : bool
#             num_workers : int
#             persistent_workers : bool
#             prefetch_factor : int
#         inner_batch_size : int
#         torchvision_model : str
#         head_pool_method : str
#         head_pool_method_kwargs : dict
#             output_size : int
#         pre_head_fc_sizes : list
#         post_head_fc_sizes : list
#         block_to_unfreeze : str
#         n_block_toInclude : int
#         head_nonlinearity : str
#         head_nonlinearity_kwargs : dict
#         lr : float
#         penalty_orthogonality : float
#         weight_decay : float
#         gamma : float
#         n_epochs : int
#         temperature : float
#         l2_alpha : float
#         augmentation : dict
#             Random_occlusion : dict
#                 prob : float
#                 size : list
#             Scale_image_sum : dict
#                 sum_val : int
#                 epsilon : float
#                 min_sub : bool
#             AddPoissonNoise : dict
#                 scaler_bounds : list
#                 prob : float
#                 base : int
#                 scaling : str
#             Horizontal_stripe_scale : dict
#                 alpha_min_max : list
#                 im_size : list
#                 prob : float
#             Horizontal_stripe_shift : dict
#                 alpha_min_max : list
#                 im_size : list
#                 prob : float
#             RandomHorizontalFlip : dict
#                 p : float
#             RandomAffine : dict
#                 degrees : list
#                 translate : list
#                 scale : list
#                 shear : list
#                 interpolation : str
#                 fill : int
#                 fillcolor : NoneType
#                 resample : NoneType
#             AddGaussianNoise : dict
#                 mean : int
#                 std : float
#                 prob : float
#             ScaleDynamicRange : dict
#                 scaler_bounds : list
#                 epsilon : float
#             WarpPoints : dict
#                 r : list
#                 cx : list
#                 cy : list
#                 dx : list
#                 dy : list
#                 n_warps : int
#                 prob : float
#                 img_size_in : list
#                 img_size_out : list
#             TileChannels : dict
#                 dim : int
#                 n_channels : int
#     net : dict
#         __repr__ : str
#     ROI_images_rs : ndarray
#     transforms : dict
#         __repr__ : str
#     dataset : dict
#         X : dict
#             __repr__ : str
#         y : dict
#             __repr__ : str
#         idx : dict
#             __repr__ : str
#         n_samples : int
#         transform : dict
#             __repr__ : str
#         n_transforms : int
#     dataloader : dict
#         __repr__ : str
#     latents : dict
#         __repr__ : str
# swt : dict
#     _verbose : bool
#     _device : str
#     swt : dict
#         __repr__ : str
#     latents : dict
#         __repr__ : str
# sim : dict
#     _algo_sf : str
#     _kwargs_sf : dict
#     _verbose : bool
#     _n_workers : int
#     _frame_height : int
#     _frame_width : int
#     blocks : list
#     _centers_y : ndarray
#     _centers_x : ndarray
#     idxPixels_block : list
#     _n_sessions : int
#     _sf_maskPower : float
#     sf_cat : dict
#         _shape : list
#         maxprint : int
#         indices : ndarray
#         indptr : ndarray
#         data : ndarray
#         _has_sorted_indices : bool
#     s_SWT : dict
#         _shape : list
#         maxprint : int
#         indices : ndarray
#         indptr : ndarray
#         data : ndarray
#         _has_canonical_format : bool
#         _has_sorted_indices : bool
#     s_sf : dict
#         _shape : list
#         maxprint : int
#         indices : ndarray
#         indptr : ndarray
#         data : ndarray
#         _has_canonical_format : bool
#         _has_sorted_indices : bool
#     s_NN : dict
#         _shape : list
#         maxprint : int
#         indices : ndarray
#         indptr : ndarray
#         data : ndarray
#         _has_canonical_format : bool
#         _has_sorted_indices : bool
#     s_sesh : dict
#         _shape : list
#         maxprint : int
#         indices : ndarray
#         indptr : ndarray
#         data : ndarray
#         _has_canonical_format : bool
#         _has_sorted_indices : bool
#     s_NN_z : dict
#         _shape : list
#         maxprint : int
#         indices : ndarray
#         indptr : ndarray
#         data : ndarray
#         _has_canonical_format : bool
#         _has_sorted_indices : bool
#     s_SWT_z : dict
#         _shape : list
#         maxprint : int
#         indices : ndarray
#         indptr : ndarray
#         data : ndarray
#         _has_canonical_format : bool
#         _has_sorted_indices : bool
# clusterer : dict
#     s_sf : dict
#         _shape : list
#         maxprint : int
#         indices : ndarray
#         indptr : ndarray
#         data : ndarray
#         _has_canonical_format : bool
#         _has_sorted_indices : bool
#     s_NN_z : dict
#         _shape : list
#         maxprint : int
#         indices : ndarray
#         indptr : ndarray
#         data : ndarray
#         _has_canonical_format : bool
#         _has_sorted_indices : bool
#     s_SWT_z : dict
#         _shape : list
#         maxprint : int
#         indices : ndarray
#         indptr : ndarray
#         data : ndarray
#         _has_canonical_format : bool
#         _has_sorted_indices : bool
#     s_sesh : dict
#         _shape : list
#         maxprint : int
#         indices : ndarray
#         indptr : ndarray
#         data : ndarray
#     s_sesh_inv : dict
#         _shape : list
#         maxprint : int
#         indices : ndarray
#         indptr : ndarray
#         data : ndarray
#     _verbose : bool
#     bounds_findParameters : dict
#         power_NN : list
#         power_SWT : list
#         p_norm : list
#         sig_NN_kwargs_mu : list
#         sig_NN_kwargs_b : list
#         sig_SWT_kwargs_mu : list
#         sig_SWT_kwargs_b : list
#     _seed : NoneType
#     n_bins : int
#     smooth_window : int
#     checker : dict
#         bests : list
#         best : float
#         n_patience : int
#         tol_frac : float
#         max_trials : int
#         max_duration : int
#         num_trial : int
#         verbose : bool
#     study : dict
#         __repr__ : str
#     _fn_smooth : dict
#     best_params : dict
#         power_NN : float
#         power_SWT : float
#         p_norm : float
#         sig_NN_kwargs : dict
#             mu : float
#             b : float
#         sig_SWT_kwargs : dict
#             mu : float
#             b : float
#     kwargs_makeConjunctiveDistanceMatrix_best : dict
#         power_SF : NoneType
#         power_NN : float
#         power_SWT : float
#         p_norm : float
#         sig_SF_kwargs : NoneType
#         sig_NN_kwargs : dict
#             mu : float
#             b : float
#         sig_SWT_kwargs : dict
#             mu : float
#             b : float
#     dConj : dict
#         _shape : list
#         maxprint : int
#         indices : ndarray
#         indptr : ndarray
#         data : ndarray
#     sConj : dict
#         _shape : list
#         maxprint : int
#         indices : ndarray
#         indptr : ndarray
#         data : ndarray
#     distributions_mixing : dict
#         kwargs_makeConjunctiveDistanceMatrix : dict
#             power_SF : NoneType
#             power_NN : float
#             power_SWT : float
#             p_norm : float
#             sig_SF_kwargs : NoneType
#             sig_NN_kwargs : dict
#                 mu : float
#                 b : float
#             sig_SWT_kwargs : dict
#                 mu : float
#                 b : float
#         dens_same_crop : dict
#             __repr__ : str
#         dens_same : dict
#             __repr__ : str
#         dens_diff : dict
#             __repr__ : str
#         dens_all : dict
#             __repr__ : str
#         edges : dict
#             __repr__ : str
#         d_crossover : float
#     d_cutoff : float64
#     graph_pruned : dict
#         _shape : list
#         maxprint : int
#         indices : ndarray
#         indptr : ndarray
#         data : ndarray
#     s_sf_pruned : dict
#         _shape : list
#         maxprint : int
#         data : ndarray
#         indices : ndarray
#         indptr : ndarray
#         _has_sorted_indices : bool
#     s_NN_pruned : dict
#         _shape : list
#         maxprint : int
#         data : ndarray
#         indices : ndarray
#         indptr : ndarray
#         _has_sorted_indices : bool
#     s_SWT_pruned : dict
#         _shape : list
#         maxprint : int
#         data : ndarray
#         indices : ndarray
#         indptr : ndarray
#         _has_sorted_indices : bool
#     s_sesh_pruned : dict
#         _shape : list
#         maxprint : int
#         data : ndarray
#         indices : ndarray
#         indptr : ndarray
#         _has_sorted_indices : bool
#     dConj_pruned : dict
#         _shape : list
#         maxprint : int
#         data : ndarray
#         indices : ndarray
#         indptr : ndarray
#         _has_sorted_indices : bool
#     sConj_pruned : dict
#         _shape : list
#         maxprint : int
#         data : ndarray
#         indices : ndarray
#         indptr : ndarray
#         _has_sorted_indices : bool
#     hdbs : dict
#         __repr__ : str
#     labels : ndarray
#     violations_labels : ndarray
#     quality_metrics : dict
#         cluster_labels_unique : ndarray
#         cluster_intra_means : ndarray
#         cluster_intra_mins : ndarray
#         cluster_intra_maxs : ndarray
#         cluster_silhouette : ndarray
#         sample_silhouette : ndarray
#         hdbscan : dict
#             sample_outlierScores : ndarray
#             sample_probabilities : ndarray
#         sequentialHungarian : NoneType
