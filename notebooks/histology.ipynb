# %%
# %reload_ext autoreload
# %autoreload 2

from vrAnalysis2.syd.histology import HistologyViewer

# %%
viewer = HistologyViewer()
viewer.show()

# %%
from matplotlib import pyplot as plt
fig = viewer.plot(viewer.state)
ax = plt.gca()
ax.set_xlim(650, 750)
ax.set_ylim(200, 100)
plt.show()
