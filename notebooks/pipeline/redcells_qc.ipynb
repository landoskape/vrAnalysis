# %%
# %reload_ext autoreload
# %autoreload 2

from _old_vrAnalysis.session import vrExperiment, redCellProcessing
from _old_vrAnalysis.redgui import redCellGUI as rgui
from vrAnalysis.database import get_database
from vrAnalysis.sessions import B2Session
sessiondb = get_database("vrSessions")

# %%
# Below is the "pipeline" for each mouse

# %%
# Start by checking which if any red cell parameters haven't been saved in any sessions
# (Note - this is using my original GUI rather than cellector style processing)
for ses in sessiondb.iter_sessions(imaging=True):
    saved_one = [str(so.name) for so in ses.get_saved_one()]
    saved_one_cutoffs = [so for so in saved_one if "minMaxCutoff" in so]
    params = [so[so.find("Red"):so.find(".")] for so in saved_one_cutoffs]
    if len(params) > 0:
        params_print = ", ".join([str(so) for so in params])
    else:
        params_print = "<<<<<<<<<<<<<<<<< NONE FOUND!!!!! >>>>>>>>>>>>>>>>>>>"
        print(ses, params_print)
# Out:
# B2Session(mouse_name='ATL079', date='2025-10-29', session_id='701') <<<<<<<<<<<<<<<<< NONE FOUND!!!!! >>>>>>>>>>>>>>>>>>>

# %%
# Get the sessions for a given mouse (based on which mice haven't been processed from above)
ises = sessiondb.iter_sessions(imaging=True, mouseName="ATL079", dontTrack=False)
for ses in ises:
    print(ses)
# Out:
# B2Session(mouse_name='ATL079', date='2025-10-29', session_id='701')

# %%
# choose a session by picking the mouse name, datestring, and session ID.
session = ises[0]
mouseName = session.mouse_name
dateString = session.date
sessionid = session.session_id
ses = vrExperiment(mouseName, dateString, sessionid)
print(ses)
# Out:
# ATL079_2025-10-29_701

# %%
# Load the experiment object, red cell processing object, and open the GUI
vrexp = vrExperiment(mouseName, dateString, sessionid)
redCell = redCellProcessing(vrexp) # create red cell processing object
redSelection = rgui.redSelectionGUI(redCell) # open the GUI
# Out:
# Warning: mpciROIs.redCellIdx.npy already exists in D:\localData\ATL079\2025-10-29\701\oneData. Overwriting...
# Warning: mpciROIs.redCellManualAssignments.npy already exists in D:\localData\ATL079\2025-10-29\701\oneData. Overwriting...
# Red Cell curation choices are saved for session ATL079/2025-10-29/701
# Warning: mpciROIs.redCellIdx.npy already exists in D:\localData\ATL079\2025-10-29\701\oneData. Overwriting...
# Warning: mpciROIs.redCellManualAssignments.npy already exists in D:\localData\ATL079\2025-10-29\701\oneData. Overwriting...
# Warning: parametersRedS2P.minMaxCutoff.npy already exists in D:\localData\ATL079\2025-10-29\701\oneData. Overwriting...
# Warning: parametersRedDotProduct.minMaxCutoff.npy already exists in D:\localData\ATL079\2025-10-29\701\oneData. Overwriting...
# Warning: parametersRedPearson.minMaxCutoff.npy already exists in D:\localData\ATL079\2025-10-29\701\oneData. Overwriting...
# Warning: parametersRedPhaseCorrelation.minMaxCutoff.npy already exists in D:\localData\ATL079\2025-10-29\701\oneData. Overwriting...
# Red Cell curation choices are saved for session ATL079/2025-10-29/701

# %%
for ses in sessiondb.iterSessionNeedRedCellQC(mouseName=mouseName):
    print(ses)
# Out:
# ATL079_2025-10-29_701

# %%
# Copy criterion from one session to another
copyCriterionFrom = redCellProcessing(mouseName, dateString, sessionid, autoload=False)
for ses in sessiondb.iterSessionNeedRedCellQC(mouseName=mouseName):
    redCell = redCellProcessing(ses, autoload=False)
    redCell.updateFromSession(copyCriterionFrom)
# Out:
# Warning: mpciROIs.redCellIdx.npy already exists in D:\localData\ATL076\2025-07-29\702\oneData. Overwriting...
# Red Cell curation choices are saved for session ATL076/2025-07-29/702
# Warning: mpciROIs.redCellIdx.npy already exists in D:\localData\ATL076\2025-07-31\701\oneData. Overwriting...
# Red Cell curation choices are saved for session ATL076/2025-07-31/701
# Warning: mpciROIs.redCellIdx.npy already exists in D:\localData\ATL076\2025-08-04\701\oneData. Overwriting...
# Red Cell curation choices are saved for session ATL076/2025-08-04/701
# Warning: mpciROIs.redCellIdx.npy already exists in D:\localData\ATL076\2025-08-05\701\oneData. Overwriting...
# Red Cell curation choices are saved for session ATL076/2025-08-05/701
# Warning: mpciROIs.redCellIdx.npy already exists in D:\localData\ATL076\2025-08-06\701\oneData. Overwriting...
# Red Cell curation choices are saved for session ATL076/2025-08-06/701
# Warning: mpciROIs.redCellIdx.npy already exists in D:\localData\ATL076\2025-08-07\703\oneData. Overwriting...
# Red Cell curation choices are saved for session ATL076/2025-08-07/703
# Warning: mpciROIs.redCellIdx.npy already exists in D:\localData\ATL076\2025-08-08\702\oneData. Overwriting...
# Red Cell curation choices are saved for session ATL076/2025-08-08/702
# Warning: mpciROIs.redCellIdx.npy already exists in D:\localData\ATL076\2025-08-13\701\oneData. Overwriting...
# Red Cell curation choices are saved for session ATL076/2025-08-13/701
# Warning: mpciROIs.redCellIdx.npy already exists in D:\localData\ATL076\2025-08-14\703\oneData. Overwriting...
# Warning: parametersRedS2P.minMaxCutoff.npy already exists in D:\localData\ATL076\2025-08-14\703\oneData. Overwriting...
# Warning: parametersRedDotProduct.minMaxCutoff.npy already exists in D:\localData\ATL076\2025-08-14\703\oneData. Overwriting...
# Warning: parametersRedPearson.minMaxCutoff.npy already exists in D:\localData\ATL076\2025-08-14\703\oneData. Overwriting...
# Warning: parametersRedPhaseCorrelation.minMaxCutoff.npy already exists in D:\localData\ATL076\2025-08-14\703\oneData. Overwriting...
# Red Cell curation choices are saved for session ATL076/2025-08-14/703
# Warning: mpciROIs.redCellIdx.npy already exists in D:\localData\ATL076\2025-08-19\704\oneData. Overwriting...
# Red Cell curation choices are saved for session ATL076/2025-08-19/704
# Warning: mpciROIs.redCellIdx.npy already exists in D:\localData\ATL076\2025-08-20\702\oneData. Overwriting...
# Red Cell curation choices are saved for session ATL076/2025-08-20/702
# Warning: mpciROIs.redCellIdx.npy already exists in D:\localData\ATL076\2025-08-21\703\oneData. Overwriting...
# Red Cell curation choices are saved for session ATL076/2025-08-21/703
# Warning: mpciROIs.redCellIdx.npy already exists in D:\localData\ATL076\2025-08-22\702\oneData. Overwriting...
# Red Cell curation choices are saved for session ATL076/2025-08-22/702
# Warning: mpciROIs.redCellIdx.npy already exists in D:\localData\ATL076\2025-08-26\702\oneData. Overwriting...
# Red Cell curation choices are saved for session ATL076/2025-08-26/702
# Warning: mpciROIs.redCellIdx.npy already exists in D:\localData\ATL076\2025-08-27\702\oneData. Overwriting...
# Red Cell curation choices are saved for session ATL076/2025-08-27/702
# Warning: mpciROIs.redCellIdx.npy already exists in D:\localData\ATL076\2025-08-28\702\oneData. Overwriting...
# Red Cell curation choices are saved for session ATL076/2025-08-28/702
